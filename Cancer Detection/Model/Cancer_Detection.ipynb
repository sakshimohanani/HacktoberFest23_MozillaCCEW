# %%
#Import Necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sm

# %%
# loading the data from sklearn
import sklearn.datasets
breast_cancer_dataset = sklearn.datasets.load_breast_cancer()

# %%
# loading the data to a data frame
df = pd.DataFrame(breast_cancer_dataset.data, columns = breast_cancer_dataset.feature_names)

# %%
# adding the 'target' column to the data frame
df['label'] = breast_cancer_dataset.target

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
#information about the dataset
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
# checking for missing values
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# label                      0
# dtype: int64

# %% [markdown]
#  **Data Visualisation**

# %%
# Histograms of specific features
selected_feature = "mean area"
sm.histplot(data=X, x=selected_feature, hue=y, kde=True)
plt.title(f"Histogram of {selected_feature}")
plt.show()

# %%
# Scatter plot for feature pairs
sm.scatterplot(x="mean radius", y="mean texture", data=X, hue=y)
plt.title("Scatter Plot of Mean Radius vs. Mean Texture")
plt.show()

# %%
# Box plots for key features by diagnosis
sm.boxplot(x=y, y="mean radius", data=X)
plt.xlabel("Diagnosis (0: Malignant, 1: Benign)")
plt.ylabel("Mean Radius")
plt.title("Mean Radius by Diagnosis")
plt.show()

# %% [markdown]
# **Correlation Matrix**

# %%
corr_matrix = df.corr()
plt.figure(figsize=(20,20))
plt.title('Correlation Matrix', fontsize = 15)
sm.heatmap(corr_matrix,annot = True ,cmap="BuPu")
# Out:
# <Axes: title={'center': 'Correlation Matrix'}>

# %% [markdown]
# Train -Test Spilt

# %%
from sklearn.model_selection import train_test_split
X = df.drop(['label'], axis = 1)
y = df['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state= 42)

# %%
# Feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %% [markdown]
# **Model Training**

# %% [markdown]
# **Logistic Regression**

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test,y_pred)*100
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 97.07602339181285

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
ypred = model.predict(X_test)
matrix = confusion_matrix(y_test,y_pred)
matrix
# Out:
# array([[ 59,   4],
#        [  1, 107]])

# %%
# Calculate the accuracy, precision, recall, and F1 score
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
acc = accuracy_score(y_test, y_pred)*100
prec = precision_score(y_test, y_pred)*100
rec = recall_score(y_test, y_pred)*100
f1 = f1_score(y_test, y_pred)*100

print(f"Accuracy: {acc}")
print(f"Precision: {prec}")
print(f"Recall: {rec}")
print(f"F1 score: {f1}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96        63
#            1       0.96      0.99      0.98       108
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.96      0.97       171
# weighted avg       0.97      0.97      0.97       171
#
# Accuracy: 97.07602339181285
# Precision: 96.3963963963964
# Recall: 99.07407407407408
# F1 score: 97.71689497716895

# %%
cm = confusion_matrix(y_test, y_pred)
plt.title('Heatmap of Confusion Matrix', fontsize = 15)
sm.heatmap(cm, annot = True)
plt.show()

# %%
# K – Nearest Neighbor Classifier
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train, y_train)
y_pred_knn = knn_classifier.predict(X_test)
accuracy_score(y_test, y_pred_knn)*100
# Out:
# 95.90643274853801

# %%
from sklearn.metrics import confusion_matrix
matrix_knn = confusion_matrix(y_test,y_pred_knn)
matrix_knn
# Out:
# array([[ 57,   6],
#        [  1, 107]])

# %%
# Calculate the accuracy, precision, recall, and F1 score
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_knn))

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
acc = accuracy_score(y_test, y_pred_knn)*100
prec = precision_score(y_test, y_pred_knn)*100
rec = recall_score(y_test, y_pred_knn)*100
f1 = f1_score(y_test, y_pred_knn)*100

print(f"Accuracy: {acc}")
print(f"Precision: {prec}")
print(f"Recall: {rec}")
print(f"F1 score: {f1}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94        63
#            1       0.95      0.99      0.97       108
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171
#
# Accuracy: 95.90643274853801
# Precision: 94.69026548672566
# Recall: 99.07407407407408
# F1 score: 96.83257918552034

# %%
# Train with Standard scaled Data
knn_classifier2 = KNeighborsClassifier()
knn_classifier2.fit(X_train_sc, y_train)
y_pred_knn_sc = knn_classifier.predict(X_test_sc)
accuracy_score(y_test, y_pred_knn_sc)*100
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 63.1578947368421

# %%
matrix_knn_sc= confusion_matrix(y_test,y_pred_knn_sc)
matrix_knn_sc
# Out:
# array([[  0,  63],
#        [  0, 108]])

# %%
# Calculate the accuracy, precision, recall, and F1 score
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_knn_sc))

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
acc = accuracy_score(y_test, y_pred_knn_sc)*100
prec = precision_score(y_test, y_pred_knn_sc)*100
rec = recall_score(y_test, y_pred_knn_sc)*100
f1 = f1_score(y_test, y_pred_knn_sc)*100

print(f"Accuracy: {acc}")
print(f"Precision: {prec}")
print(f"Recall: {rec}")
print(f"F1 score: {f1}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        63
#            1       0.63      1.00      0.77       108
#
#     accuracy                           0.63       171
#    macro avg       0.32      0.50      0.39       171
# weighted avg       0.40      0.63      0.49       171
#
# Accuracy: 63.1578947368421
# Precision: 63.1578947368421
# Recall: 100.0
# F1 score: 77.41935483870968
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# Random Forest Classification

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators = 20, criterion = 'entropy', random_state = 51)
rf_classifier.fit(X_train, y_train)
y_pred_rf = rf_classifier.predict(X_test)
accuracy_score(y_test, y_pred_rf)*100
# Out:
# 97.07602339181285

# %%
from sklearn.metrics import confusion_matrix
matrix_rf = confusion_matrix(y_test,y_pred_rf)
matrix_rf
# Out:
# array([[ 60,   3],
#        [  2, 106]])

# %%
# Calculate the accuracy, precision, recall, and F1 score
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_rf))

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
acc = accuracy_score(y_test, y_pred_rf)*100
prec = precision_score(y_test, y_pred_knn_sc)*100
rec = recall_score(y_test, y_pred_rf)*100
f1 = f1_score(y_test, y_pred_rf)*100

print(f"Accuracy: {acc}")
print(f"Precision: {prec}")
print(f"Recall: {rec}")
print(f"F1 score: {f1}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96        63
#            1       0.97      0.98      0.98       108
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171
#
# Accuracy: 97.07602339181285
# Precision: 63.1578947368421
# Recall: 98.14814814814815
# F1 score: 97.69585253456222

# %% [markdown]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
decisiontree = DecisionTreeClassifier(criterion="entropy",max_depth=3)
decisiontree.fit(X_train, y_train)
y_pred_dt = decisiontree.predict(X_test)
accuracy_score(y_test, y_pred_dt)*100
# Out:
# 97.07602339181285

# %%
from sklearn.tree import DecisionTreeClassifier
decisiontree = DecisionTreeClassifier(criterion="entropy",max_depth=6)
decisiontree.fit(X_train, y_train)
y_pred_dt = decisiontree.predict(X_test)
accuracy_score(y_test, y_pred_dt)*100
# Out:
# 95.32163742690058

# %% [markdown]
# **Heatmap of Confusion Matrix of Logistic Regression**

# %%
cm = confusion_matrix(y_test, y_pred)
plt.title('Heatmap of Confusion Matrix', fontsize = 15)
sm.heatmap(cm, annot = True)
plt.show()

# %% [markdown]
# We have completed the Machine learning Project successfully with **97.07%** **accuracy** using Logistic Regression model which is great for ‘Breast Cancer Detection using Machine learning’.
